# %% [markdown]
# <a href="https://colab.research.google.com/github/NazarioR9/BNBR_Challenge/blob/master/notebooks/MLMRobertaBaseGenericModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Specs

# %%
# !nvidia-smi
# Out:
# Sun Jul  5 13:21:58 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #Install

# %%
# !pip install transformers catalyst --quiet

# %%
# !pip install torchcontrib --quiet

# %% [markdown]
# #Imports

# %%
import warnings
warnings.simplefilter('ignore')

# %%
import os, sys, gc
import time
import string
import subprocess
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import log_loss, f1_score, accuracy_score
from sklearn.metrics import classification_report

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
import transformers
from transformers import AutoConfig, AutoTokenizer, BartConfig, RobertaTokenizer

# %%
! cp -r ./../bnbr/ bnbr

# %%
sys.path.append('./../bnbr')

# %%
import bnbr
from bnbr.activation import *
from bnbr.data import *
from bnbr.models import *
from bnbr.loss import *
from bnbr.utils import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Envs

# %%
# !unzip ./../mlm_finetuned_models/mlm_roberta_base_

# %%
seed = 2020
seeds = [42, 5, 12]
n_folds = 10
model_name = 'roberta-base'
model_path = 'fms/'
dirs = ['models/', f'evals/{model_name}']
exts = ['.csv', '.pkl']

# %%
wm = WorkplaceManager(seed, dirs, exts)
# Out:
# Set seed to 2020.
# Deleted models/ evals/roberta-base
# Deleted .csv .pkl
# Created models/ evals/roberta-base

# %% [markdown]
# #Tokenizer

# %%
config = AutoConfig.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# #Data

# %%
path = './../data/'

# %%
os.listdir(path)

# %%
train = pd.read_csv(path+'final_train.csv')
test = pd.read_csv(path+'final_test.csv')
sample = pd.read_csv(path+'SampleSubmission.csv')

# %%
train.shape
# Out:
# (597, 7)

# %%
train.head()
# Out:
#          ID                                               text  ...  Suicide  Drugs
# 0  SUAVK39Z           i feel that it was better i die am happy  ...        0      0
# 1  9JDAGUV3                     why do i get hallucinations ?   ...        0      1
# 2  419WR1LQ   i am stressed due to lack of financial suppor...  ...        0      0
# 3  6UY7DX6Q                           why is life important ?   ...        1      0
# 4  FYC0FTFB   how could i be helped to go through the depre...  ...        0      0
#
# [5 rows x 7 columns]

# %%
train = train[['text', 'Depression', 'Alcohol', 'Suicide', 'Drugs', 'label']]

# %%
train['length'] = train['text'].apply(lambda x: len(tokenizer.encode(x)))
test['length'] = test['text'].apply(lambda x: len(tokenizer.encode(x)))

# %%
train.head()
# Out:
#                                                 text  Depression  ...  label  length
# 0           i feel that it was better i die am happy           1  ...      0      12
# 1                     why do i get hallucinations ?            0  ...      3       9
# 2   i am stressed due to lack of financial suppor...           1  ...      0      13
# 3                           why is life important ?            0  ...      2       8
# 4   how could i be helped to go through the depre...           1  ...      0      14
#
# [5 rows x 7 columns]

# %%
train.label.value_counts()
# Out:
# 0    344
# 1    132
# 2     65
# 3     56
# Name: label, dtype: int64

# %% [markdown]
# #Split in folds

# %%
train.head()
# Out:
#                                                 text  Depression  ...  label  length
# 0           i feel that it was better i die am happy           1  ...      0      12
# 1                     why do i get hallucinations ?            0  ...      3       9
# 2   i am stressed due to lack of financial suppor...           1  ...      0      13
# 3                           why is life important ?            0  ...      2       8
# 4   how could i be helped to go through the depre...           1  ...      0      14
#
# [5 rows x 7 columns]

# %%
kf = StratifiedKFold(n_folds)
#train['fold'] = 0
for fold, (tr_index, val_index) in enumerate(kf.split(train.index, train.label)):
  train.loc[val_index, 'fold'] = fold

# %%
train.head()
# Out:
#                                                 text  Depression  ...  length  fold
# 0           i feel that it was better i die am happy           1  ...      12   0.0
# 1                     why do i get hallucinations ?            0  ...       9   0.0
# 2   i am stressed due to lack of financial suppor...           1  ...      13   0.0
# 3                           why is life important ?            0  ...       8   0.0
# 4   how could i be helped to go through the depre...           1  ...      14   0.0
#
# [5 rows x 8 columns]

# %% [markdown]
# #Utilities

# %%
class GlobalConfig:
  accumulate_grad_batches = 1
  activation = torch.softmax
  batch_size = 32
  clip_grad = False
  epochs = 10
  folds = n_folds
  hidden_multiplier = 1
  high_dropout = 0.5 #.3
  id = 0
  L = 1
  loss = MHMLoss('ce', 10)
  loss_name = 'ce'
  low_dropout = 0.3
  lr = 4.5e-5
  max_grad_norm = 1.0
  max_tokens = None #
  mhm_activation = Mish()
  model_name = model_name
  model_path = model_path
  multi_samp_nb = 3
  n = 11
  output_hidden_states = True
  reinit = False
  scheduler = False
  swa = False
  swa_start = 4
  swa_freq = 1
  swa_lr = 3e-5
  task = 'train'
  warmup_steps = 0
  

  def __init__(self, xp_nb=0):
    self.xp_nb = xp_nb
    self._name()
    self._lightweight()

  def update(self, **kwargs):
    for name in kwargs.keys():
      if hasattr(self, name):
        setattr(self, name, kwargs[name])

  def _lightweight(self):
    self.fold = 0
    self.train_df = None
    self.test_df = None
    self.val_df = None

  def save(self, path=''):
    self._lightweight()
    
    with open(path+self.name, 'wb') as f:
      pickle.dump(self, f)
      f.close()

  def _name(self):
    if not hasattr(self, 'name'):
      vocab = string.ascii_letters + string.digits
      for i in range(self.xp_nb):
        n = ''
        for _ in range(10):
          n += vocab[random.randint(0, len(vocab)-1)]

      self.name = 'config_'+n+'.pkl'

# %%
global global_config
global_config = GlobalConfig(0)

# %%
def run_fold(score_pkl='cv_score.pkl'):
  fold_scores = []
  print_dict_list = {}

  try:
    with open(score_pkl, 'rb') as f:
      cv_score = pickle.load(f)
      f.close()
  except FileNotFoundError:
    cv_score = 0

  completed = len(os.listdir('models/'))

  for fold in train.fold.unique():
    if fold < completed: continue

    # df_train = balance_training(train.iloc[tr_index].copy())
    df_train = train[train.fold != fold].copy()
    df_val = train[train.fold == fold].copy()
    print_dict_list[fold] = []
    best_score = np.inf

    global_config.update(
      fold = fold,
      train_df=df_train,
      val_df=df_val
    )


    trainer = Trainer(global_config)
    es = EarlyStopping()
    
    for epoch in range(global_config.epochs):
      trainer.fit_one_epoch(epoch)
      # es.update(trainer.scores[epoch][-1])

      # if es.stop and epoch >=5:
      #   break

    trainer.save_best_eval()
    trainer.evaluate_post_processing()

    cv_score += trainer.best_log

    os.system(f"rm {score_pkl}")
    with open(score_pkl, 'wb') as f:
      pickle.dump(cv_score, f)
      f.close()

    trainer = None, None
    del trainer, df_train, df_val
    torch.cuda.empty_cache()
    gc.collect()

# %%
def run_prediction(path='models/'):
  preds = []
  global_config.update(
      task='test',
      test_df=test
    )

  for fold in train.fold.unique():

    module = LightTrainingModule(global_config)
    module.load_state_dict(torch.load(path+f'model_{fold}.bin'))
    trainer = Trainer(global_config, module=module)
    
    trainer.predict()
    pred = trainer.get_preds()

    preds.append(pred)

    module, trainer = None, None
    del trainer, module
    torch.cuda.empty_cache()
    gc.collect()

  return preds

# %% [markdown]
# #The Torch Way

# %% [markdown]
# ##Run folds

# %%
gc.collect()
# Out:
# 817

# %%
run_fold()
# Out:
# ____________________________________________________________________________________________________
# Fold  9.0
# 	____________________________________________________________________________________________________
# 	| Epoch: 0 - Loss: 1.15813 - ValLoss: 1.07970 - Log: 1.07971 - F1: 0.41684 - LogF1: 0.22295
# 	____________________________________________________________________________________________________
# 	| Epoch: 1 - Loss: 0.93292 - ValLoss: 0.77587 - Log: 0.77587 - F1: 0.65357 - LogF1: 0.43885
# 	____________________________________________________________________________________________________
# 	| Epoch: 2 - Loss: 0.59933 - ValLoss: 0.62572 - Log: 0.62572 - F1: 0.73155 - LogF1: 0.55292
# 	____________________________________________________________________________________________________
# 	| Epoch: 3 - Loss: 0.38360 - ValLoss: 0.52326 - Log: 0.52326 - F1: 0.87168 - LogF1: 0.67421
# 	____________________________________________________________________________________________________
# 	| Epoch: 4 - Loss: 0.27745 - ValLoss: 0.46248 - Log: 0.46248 - F1: 0.83191 - LogF1: 0.68472
# 	____________________________________________________________________________________________________
# 	| Epoch: 5 - Loss: 0.17386 - ValLoss: 0.44504 - Log: 0.44504 - F1: 0.87990 - LogF1: 0.71743
# 	____________________________________________________________________________________________________
# 	| Epoch: 6 - Loss: 0.12488 - ValLoss: 0.48507 - Log: 0.48507 - F1: 0.91038 - LogF1: 0.71266
# 	____________________________________________________________________________________________________
# 	| Epoch: 7 - Loss: 0.06963 - ValLoss: 0.65572 - Log: 0.65572 - F1: 0.88292 - LogF1: 0.61360
# 	____________________________________________________________________________________________________
# 	| Epoch: 8 - Loss: 0.04897 - ValLoss: 0.55383 - Log: 0.55383 - F1: 0.87668 - LogF1: 0.66143
# 	____________________________________________________________________________________________________
# 	| Epoch: 9 - Loss: 0.08714 - ValLoss: 0.58601 - Log: 0.58601 - F1: 0.90448 - LogF1: 0.65923
# 	____________________________________________________________________________________________________
# 	| [PP DRUGS]  [BEST SCORE]: 0.44503881231651543 - [POST PROCESS SCORE]: 0.4494683903150737 - [VERDICT]: False
# 	____________________________________________________________________________________________________
# 	| [PP ALCOH]  [BEST SCORE]: 0.44503881231651543 - [POST PROCESS SCORE]: 0.6487571860802914 - [VERDICT]: False
# 	____________________________________________________________________________________________________
# 	| [BEST SCORE]: 0.44503881231651543 - [POST PROCESS SCORE]: 1.6287054745566651 - [VERDICT]: False

# %%
# wm.clear(['evals/', 'models/'])

# %% [markdown]
# # CrossVal Score

# %%
cvl = CrossValLogger(train, n_folds, path=f'evals/{model_name}/')

# %%
score1, score2 = cvl.show_results(True)
# Out:
# OOF_CV_SCORE: 0.39070 | OVR_SCORE: 0.38655

# %%
gc.collect()
# Out:
# 30

# %% [markdown]
# #Save config

# %%
global_config.save()

# %% [markdown]
# ##Prediction

# %%
# %%time
preds = run_prediction()
# Out:
# CPU times: user 1min 1s, sys: 6.81 s, total: 1min 8s
# Wall time: 3min 34s

# %%
raw_outputs = np.mean(preds, axis=0)

# %% [markdown]
# #Submission

# %%
# !mkdir ./../submissions

# %%
spath = './../submissions/'

# %%
sample[["Depression","Alcohol","Suicide","Drugs"]] = raw_outputs

# %%
sample.to_csv(spath + f'{model_name}__.csv', index=False)

# %%
sample.head()
# Out:
#          ID  Depression   Alcohol   Suicide     Drugs
# 0  02V56KMO    0.726017  0.025086  0.227651  0.021246
# 1  03BMGTOK    0.990635  0.001721  0.006303  0.001341
# 2  03LZVFM6    0.991956  0.001654  0.005111  0.001280
# 3  0EPULUM5    0.991569  0.001625  0.005580  0.001226
# 4  0GM4C5GD    0.006329  0.232706  0.016765  0.744201

# %%
sample.describe()
# Out:
#        Depression     Alcohol     Suicide       Drugs
# count  309.000000  309.000000  309.000000  309.000000
# mean     0.544079    0.215507    0.146051    0.094363
# std      0.446554    0.368990    0.258686    0.233527
# min      0.004002    0.001548    0.004506    0.001207
# 25%      0.009855    0.001800    0.005514    0.001420
# 50%      0.765412    0.016647    0.008498    0.012684
# 75%      0.990440    0.122572    0.124758    0.035496
# max      0.992491    0.967638    0.903291    0.898146

# %%
sample[["Depression","Alcohol","Suicide","Drugs"]].apply(np.argmax, axis=1).value_counts()
# Out:
# 0    171
# 1     64
# 2     48
# 3     26
# dtype: int64
